# %% [markdown]
# <a href="https://colab.research.google.com/github/wonbinown/dmu_lecture/blob/main/hicolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi colab")
# Out:
# hi colab
